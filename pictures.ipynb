# %% [markdown]
# ### This is a test of GIT versioning
# Lets Practice!!!

# %%
import pandas as pd


def greeting():
    print('Hello World!!')


greeting()
# Out:
# Hello World!!

# %%
def add(a, b):
    return a + b


def multiply():
    ...

# %%
add(4, 6)
# Out:
# 10
