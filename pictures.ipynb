# %% [markdown]
# ### This is a test of GIT versioning
# Lets Practice!!!

# %%
import pandas as pd


def greeting():
    print('Hello World!!')


greeting()
# Out:
# Hello World!!

# %% [markdown]
# Tomorrow we will create two more functions:
#
#
#     - first function will add two numbers
#     - second function will multiply two numbers
